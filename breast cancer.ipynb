# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
# Replace with the correct dataset filename
df = pd.read_csv("C:/Users/Bhanu Mutha/OneDrive/Documents/breast cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Remove ID or unnamed columns if present
df.drop(columns=[col for col in df.columns if 'id' in col.lower() or 'unnamed' in col.lower()], inplace=True)

# %%
# Replace '?' with NaN and drop rows with missing values
df.replace('?', np.nan, inplace=True)
df.dropna(inplace=True)

# %%
# Convert diagnosis column to numeric values: M = 1 (Malignant), B = 0 (Benign)
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %%
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
k = 5  # You can change this and test different values
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 y_pred = knn.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neighbors\_classification.py:257, in KNeighborsClassifier.predict(self, X)
#     241 def predict(self, X):
#     242     """Predict the class labels for the provided data.
#     243
#     244     Parameters
#    (...)    255         Class labels for each data sample.
#     256     """
# --> 257     check_is_fitted(self, "_fit_method")
#     258     if self.weights == "uniform":
#     259         if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     260             X, self._fit_X, self.metric
#     261         ):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1754, in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9473684210526315
# Precision: 0.9302325581395349
# Recall: 0.9302325581395349
# F1 Score: 0.9302325581395349
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        71
#            1       0.93      0.93      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
# Replace with your own data (must have same number of features)
# Example:
# new_data = [[value1, value2, ..., valueN]]
# prediction = knn.predict(scaler.transform(new_data))
# print("Prediction (0=Benign, 1=Malignant):", prediction)
